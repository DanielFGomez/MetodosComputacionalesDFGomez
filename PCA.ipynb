# %%
pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
A=matrix((loadtxt('/home/administrador/MetodosComputacionalesDatos/hands_on/')))
scatter(A[:,0],A[:,1])
print type(A)
# Out:
# <class 'numpy.matrixlib.defmatrix.matrix'>

# %%
B=matrix((A-mean(A,0)))
sigma=(B).T*(B)/(len(B)-1)
valores,vectores=eig(sigma)
scatter(array(B[:,0]),array(B[:,1]))
print vectores
# Out:
# [[-0.96754198 -0.25271035]
#  [ 0.25271035 -0.96754198]]

# %%
N=vectores.T[0].T*B.T
print vectores
scatter(array(N[1]),array(N[0]))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-99-b7df1e051c7f> in <module>()
# ----> 1 N=vectores.T[0].T*B.T
#       2 print vectores
#       3 scatter(array(N[1]),array(N[0]))
#
# /usr/lib/python2.7/dist-packages/numpy/matrixlib/defmatrix.pyc in __mul__(self, other)
#     339         if isinstance(other, (N.ndarray, list, tuple)) :
#     340             # This promotes 1-D vectors to row vectors
# --> 341             return N.dot(self, asmatrix(other))
#     342         if isscalar(other) or not hasattr(other, '__rmul__') :
#     343             return N.dot(self, other)
#
# ValueError: matrices are not aligned

# %%
def p(x):
    return 1.0/(5.0-75.0*x**2
                

x=linspace(-1,1,4)
