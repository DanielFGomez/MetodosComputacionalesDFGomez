# %%
pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
A=matrix([[2,1],[2,3]])



puntos=[[],[]]



puntosT=puntos.transpose()    
trans=dot(A,puntos).T

aPrima=trans*linalg.inv(A).T

for i in trans:
    scatter(i[0,0],i[0,1],color="r")
for i in aPrima:
    scatter(i[0,0],i[0,1])

# %%
random.random(5)
# Out:
# array([ 0.07111618,  0.23992415,  0.06645362,  0.14958808,  0.564801  ])
